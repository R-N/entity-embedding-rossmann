# %% [markdown]
# The data used for the plots are learned using the master branch without simulating data sparsity.

# %%
import pickle
from sklearn import manifold
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
with open("embeddings.pickle", 'rb') as f:
    [store_embedding, dow_embedding, year_embedding,
     month_embedding, day_embedding, german_states_embedding] = pickle.load(f)

# %%
# Load LabelEncoders
with open("les.pickle", 'rb') as f:
    les = pickle.load(f)
le_store = les[1]
le_dow = les[2]
le_month = les[5]
le_day = les[6]
le_state = les[7]

# %%
list(le_state.classes_)
# Out:
# ['BE', 'BW', 'BY', 'HB,NI', 'HE', 'HH', 'NW', 'RP', 'SH', 'SN', 'ST', 'TH']

# %%
states_names = ['Berlin', 'Baden Wuerttemberg', 'Bayern', 'Niedersachsen/Bremen', 
                'Hessen', 'Hamburg', 'Nordrhein Westfalen', 'Rheinland Pfalz',
                'Schleswig Holstein', 'Sachsen', 'Sachsen Anhalt', 'Thueringen']

# %%
tsne = manifold.TSNE(init='pca', random_state=0, method='exact', perplexity=5, learning_rate=100)
Y = tsne.fit_transform(german_states_embedding)
plt.figure(figsize=(8,8))
plt.scatter(-Y[:, 0], -Y[:, 1])
for i, txt in enumerate(states_names):
    plt.annotate(txt, (-Y[i, 0],-Y[i, 1]), xytext = (-20, 8), textcoords = 'offset points')
plt.savefig('state_embedding.pdf')

# %%
list(le_dow.classes_)
# Out:
# ['1', '2', '3', '4', '5', '6', '7']

# %%
tsne = manifold.TSNE(init='pca', random_state=0, method='exact',perplexity=5, learning_rate=100)
Y = tsne.fit_transform(dow_embedding)
names = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat','Sun']
plt.figure(figsize=(8,8))
plt.scatter(-Y[:, 0], -Y[:, 1])
for i, txt in enumerate(names):
    plt.annotate(txt, (-Y[i, 0],-Y[i, 1]), xytext = (-5, 8), textcoords = 'offset points')
plt.savefig('dow_embedding.png')

# %%
list(le_month.classes_)
# Out:
# ['1', '10', '11', '12', '2', '3', '4', '5', '6', '7', '8', '9']

# %%
tsne = manifold.TSNE(init='pca', random_state=0, method='exact', perplexity=5, learning_rate=100)
Y = tsne.fit_transform(month_embedding)
names = ['Jan', 'Oct', 'Nov', 'Dec', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep']
plt.figure(figsize=(8,8))
plt.scatter(-Y[:, 0], -Y[:, 1])
for i, txt in enumerate(names):
    plt.annotate(txt, (-Y[i, 0],-Y[i, 1]), xytext = (-5, 8), textcoords = 'offset points')
plt.savefig('month_embedding.png')

# %%
tsne = manifold.TSNE(init='pca', random_state=0, method='exact', perplexity=5, learning_rate=100, verbose=2, early_exaggeration=1)
Y = tsne.fit_transform(store_embedding)
names = list(le_store.classes_)
plt.figure(figsize=(20,20))
plt.scatter(-Y[:, 0], -Y[:, 1])
for i, txt in enumerate(names):
    plt.annotate(txt, (-Y[i, 0],-Y[i, 1]))
plt.savefig('store_embedding.png')
# Out:
# [t-SNE] Computing pairwise distances...
# [t-SNE] Computed conditional probabilities for sample 1000 / 1115
# [t-SNE] Computed conditional probabilities for sample 1115 / 1115
# [t-SNE] Mean sigma: 0.059599
# [t-SNE] Iteration 50: error = 2.3381981, gradient norm = 0.0035338 (50 iterations in 2.189s)
# [t-SNE] Iteration 100: error = 1.9348994, gradient norm = 0.0024700 (50 iterations in 1.970s)
# [t-SNE] Iteration 150: error = 1.7582030, gradient norm = 0.0017019 (50 iterations in 1.987s)
# [t-SNE] Iteration 200: error = 1.6545850, gradient norm = 0.0012146 (50 iterations in 1.942s)
# [t-SNE] Iteration 250: error = 1.5851836, gradient norm = 0.0008867 (50 iterations in 1.952s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 1.585184
# [t-SNE] Iteration 300: error = 1.5387308, gradient norm = 0.0005703 (50 iterations in 2.165s)
# [t-SNE] Iteration 350: error = 1.4652646, gradient norm = 0.0004622 (50 iterations in 1.854s)
# [t-SNE] Iteration 400: error = 1.4120237, gradient norm = 0.0003766 (50 iterations in 1.835s)
# [t-SNE] Iteration 450: error = 1.3757334, gradient norm = 0.0002846 (50 iterations in 1.799s)
# [t-SNE] Iteration 500: error = 1.3507888, gradient norm = 0.0002284 (50 iterations in 1.787s)
# [t-SNE] Iteration 550: error = 1.3328524, gradient norm = 0.0001916 (50 iterations in 1.855s)
# [t-SNE] Iteration 600: error = 1.3194227, gradient norm = 0.0001587 (50 iterations in 2.151s)
# [t-SNE] Iteration 650: error = 1.3091135, gradient norm = 0.0001368 (50 iterations in 1.941s)
# [t-SNE] Iteration 700: error = 1.3004938, gradient norm = 0.0001264 (50 iterations in 1.879s)
# [t-SNE] Iteration 750: error = 1.2941478, gradient norm = 0.0001052 (50 iterations in 1.933s)
# [t-SNE] Iteration 800: error = 1.2889104, gradient norm = 0.0000943 (50 iterations in 1.913s)
# [t-SNE] Iteration 850: error = 1.2844881, gradient norm = 0.0000861 (50 iterations in 1.919s)
# [t-SNE] Iteration 900: error = 1.2807060, gradient norm = 0.0000827 (50 iterations in 1.983s)
# [t-SNE] Iteration 950: error = 1.2774952, gradient norm = 0.0000755 (50 iterations in 1.959s)
# [t-SNE] Iteration 1000: error = 1.2746964, gradient norm = 0.0000687 (50 iterations in 2.032s)
# [t-SNE] KL divergence after 1000 iterations: 1.274696
